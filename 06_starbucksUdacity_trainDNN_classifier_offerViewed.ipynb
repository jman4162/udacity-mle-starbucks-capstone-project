# %%
import pandas as pd
import numpy as np
import math
import json
% matplotlib inline

from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

filePath = "/content/drive/My Drive/Udacity-MLE-Capstone-Starbucks-data/"

# read in the json files
#portfolio = pd.read_json(filePath+'data/portfolio.json', orient='records', lines=True)
#profile = pd.read_json(filePath+'data/profile.json', orient='records', lines=True)
#transcript = pd.read_json(filePath+'data/transcript.json', orient='records', lines=True)

predictOfferViewed = 1

if predictOfferViewed:
  # Load data for training
  X = pd.read_pickle(filePath+'dataOfferViewedX.pkl')
  Y = pd.read_pickle(filePath+'dataOfferViewedY.pkl')
else:
  # Load data for training
  X = pd.read_pickle(filePath+'dataOfferCompX.pkl')
  Y = pd.read_pickle(filePath+'dataOfferCompY.pkl')

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# setting up torch device:
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('GPU is available.' if torch.cuda.is_available() else 'GPU is NOT avaliable, using CPU.')
# Out:
# GPU is available.

# %% [markdown]
# # Prepare and Split Data

# %%
Y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 66496    0
# 66497    0
# 66498    1
# 66499    1
# 66500    0
# Name: offer_viewed, Length: 66501, dtype: int64

# %%
X
# Out:
#        difficulty  duration  reward  ...  gender_F  gender_M  gender_O
# 0             0.5  0.571429     1.0  ...         0         1         0
# 1             0.5  0.571429     1.0  ...         0         1         0
# 2             0.0  0.142857     0.0  ...         0         1         0
# 3             1.0  1.000000     0.5  ...         0         1         0
# 4             1.0  1.000000     0.5  ...         0         1         0
# ...           ...       ...     ...  ...       ...       ...       ...
# 66496         0.5  0.571429     0.2  ...         1         0         0
# 66497         0.5  0.571429     0.2  ...         1         0         0
# 66498         0.5  0.571429     0.2  ...         1         0         0
# 66499         0.5  0.571429     0.2  ...         0         1         0
# 66500         0.5  0.571429     0.2  ...         0         1         0
#
# [66501 rows x 17 columns]

# %%
# Print columns used as model features
print(X.columns)
# Out:
# Index(['difficulty', 'duration', 'reward', 'chan_social', 'chan_email',
#        'chan_web', 'chan_mobile', 'offer_type_bogo', 'offer_type_discount',
#        'offer_type_informational', 'age', 'income', 'joinDate_month',
#        'joinDate_year', 'gender_F', 'gender_M', 'gender_O'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = preprocessing.MinMaxScaler()
X = min_max_scaler.fit_transform(X)

# We split the dataset into 2/3 training and 1/3 testing sets.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)

# Then we split the training set further into 2/3 training and 1/3 validation sets.
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, shuffle=True)

# %%
print(X_train)
print(X_train.shape)
# Out:
# [[0.5        0.57142857 1.         ... 1.         0.         0.        ]
#  [0.5        0.57142857 0.2        ... 0.         1.         0.        ]
#  [1.         1.         0.5        ... 0.         1.         0.        ]
#  ...
#  [0.5        0.57142857 1.         ... 0.         1.         0.        ]
#  [0.25       0.57142857 0.5        ... 1.         0.         0.        ]
#  [0.35       0.57142857 0.3        ... 0.         1.         0.        ]]
# (42560, 17)

# %%
print(Y_train)
print(Y_train.shape)
# Out:
# 2279     1
# 44876    1
# 2024     1
# 40162    1
# 6011     0
#         ..
# 27291    0
# 60355    0
# 2906     1
# 5035     0
# 18546    1
# Name: offer_viewed, Length: 42560, dtype: int64
# (42560,)

# %%
#test_tensor = torch.Tensor(X.values)

# Convert data into torch.Tensor:
X_train = torch.Tensor(X_train).to(device)
X_val = torch.Tensor(X_val).to(device)
X_test = torch.Tensor(X_test).to(device)

Y_train = torch.Tensor(Y_train.values).to(device)
Y_val = torch.Tensor(Y_val.values).to(device)
Y_test = torch.Tensor(Y_test.values).to(device)

# Create datasets for the dataloaders:
train_data = TensorDataset(X_train, Y_train)
test_data = TensorDataset(X_test, Y_test)
val_data = TensorDataset(X_val, Y_val)

# print out some data stats
print('# of training samples: ', len(train_data))
print('# of validation samples: ', len(val_data))
print('# of test samples: ', len(test_data))

batch_size = 128

# Creating the data loaders:
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)

loaders = {
    'train': train_loader,
    'valid': val_loader,
    'test': test_loader
}
# Out:
# # of training samples:  42560
# # of validation samples:  10640
# # of test samples:  13301

# %%
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# torch.Size([42560, 17]) torch.Size([42560])
# torch.Size([13301, 17]) torch.Size([13301])

# %%
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

n_classes = 1 # Number of classes
n_features = 17 # Number of features

# define the DNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self, n_features):
        super(Net, self).__init__()
        ## Define layers of a DNN
        
        self.fc1 = nn.Linear(n_features, 32)
        # linear layer (17 -> 32)
        self.fc2 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc3 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc4 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc5 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc6 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc7 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc8 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc9 = nn.Linear(32, 32)
        # linear layer (32 -> 16)
        self.fc10 = nn.Linear(32, 16)
        # linear layer (16 -> 8)
        self.fc11 = nn.Linear(16, 8)
        # linear layer (8 -> 1)
        self.fc12 = nn.Linear(8, n_classes)
        
        # dropout layer (p=0.25)
        self.dropout = nn.Dropout(0.25)
    
    def forward(self, x):
        ## Define forward behavior
        
        # add 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        
        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc3(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc4(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc5(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc6(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc7(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc8(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc9(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.relu(self.fc10(x))

        #print("a4: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 3rd hidden layer
        x = F.relu(self.fc11(x))

        #print("a4: ",x.shape)
        # add dropout layer
        #x = self.dropout(x)
        # add 3rd hidden layer
        x = self.fc12(x)

        #print("a5: ",x.shape)
        
        return x
    

# instantiate the CNN
model = Net(n_features)
print(model)

# move tensors to GPU if CUDA is available
if use_cuda:
    model.cuda()
# Out:
# Net(
#   (fc1): Linear(in_features=17, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=32, bias=True)
#   (fc6): Linear(in_features=32, out_features=32, bias=True)
#   (fc7): Linear(in_features=32, out_features=32, bias=True)
#   (fc8): Linear(in_features=32, out_features=32, bias=True)
#   (fc9): Linear(in_features=32, out_features=32, bias=True)
#   (fc10): Linear(in_features=32, out_features=16, bias=True)
#   (fc11): Linear(in_features=16, out_features=8, bias=True)
#   (fc12): Linear(in_features=8, out_features=1, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )

# %%
from torch import optim

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    print("Begin training...")
    
    train_losses, valid_losses = [], []
    for epoch in range(1, n_epochs+1):
        #print("Epoch: ",epoch)
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            #if batch_idx % 100 == 0:
                #print("Epoch: {}, Batch: {}".format(epoch,batch_idx))
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            # clear the gradients of all optimized variables
            optimizer.zero_grad()

            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            output = output.view(-1)
            target = target.unsqueeze(0).view(-1)

            # calculate the batch loss
            loss = criterion(output, target)
            
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            
            # perform a single optimization step (parameter update)
            optimizer.step()
            
            # record the average training loss, using something like
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
        ######################    
        # validate the model #
        ######################
        with torch.no_grad():
          model.eval()
          for batch_idx, (data, target) in enumerate(loaders['valid']):
              # move to GPU
              if use_cuda:
                  data, target = data.cuda(), target.cuda()
              ## update the average validation loss

              # forward pass: compute predicted outputs by passing inputs to the model
              output = model(data)
              #output = outputs.view(1, -1)  # make it the same shape as output
              target = target.unsqueeze(0).view(-1)
              output = output.view(-1)

              # calculate the batch loss
              loss = criterion(output, target)
              
              # update average validation loss 
              valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))

        train_losses.append(train_loss)
        valid_losses.append(valid_loss)

        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min, valid_loss))
                
            valid_loss_min = valid_loss
    
    print("Training Complete!")
    # return trained model
    return model, train_losses, valid_losses

# %%
n_epochs = 300 # Number of training epochs

# train the model
model, train_losses, valid_losses = train(n_epochs, loaders, model, optimizer, 
                                          criterion, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# Begin training...
# Epoch: 1 	Training Loss: 0.553677 	Validation Loss: 0.438514
# Validation loss decreased (inf --> 0.438514).  Saving model ...
# Epoch: 2 	Training Loss: 0.454368 	Validation Loss: 0.435496
# Validation loss decreased (0.438514 --> 0.435496).  Saving model ...
# Epoch: 3 	Training Loss: 0.447790 	Validation Loss: 0.440349
# Epoch: 4 	Training Loss: 0.445561 	Validation Loss: 0.432949
# Validation loss decreased (0.435496 --> 0.432949).  Saving model ...
# Epoch: 5 	Training Loss: 0.441535 	Validation Loss: 0.435934
# Epoch: 6 	Training Loss: 0.442000 	Validation Loss: 0.427180
# Validation loss decreased (0.432949 --> 0.427180).  Saving model ...
# Epoch: 7 	Training Loss: 0.440368 	Validation Loss: 0.456372
# Epoch: 8 	Training Loss: 0.438023 	Validation Loss: 0.454955
# Epoch: 9 	Training Loss: 0.438738 	Validation Loss: 0.427194
# Epoch: 10 	Training Loss: 0.436235 	Validation Loss: 0.433140
# Epoch: 11 	Training Loss: 0.436563 	Validation Loss: 0.439902
# Epoch: 12 	Training Loss: 0.434694 	Validation Loss: 0.439675
# Epoch: 13 	Training Loss: 0.434402 	Validation Loss: 0.440789
# Epoch: 14 	Training Loss: 0.434381 	Validation Loss: 0.434619
# Epoch: 15 	Training Loss: 0.434323 	Validation Loss: 0.438528
# Epoch: 16 	Training Loss: 0.433738 	Validation Loss: 0.435439
# Epoch: 17 	Training Loss: 0.433827 	Validation Loss: 0.432068
# Epoch: 18 	Training Loss: 0.433707 	Validation Loss: 0.439648
# Epoch: 19 	Training Loss: 0.433063 	Validation Loss: 0.441882
# Epoch: 20 	Training Loss: 0.432490 	Validation Loss: 0.438319
# Epoch: 21 	Training Loss: 0.433190 	Validation Loss: 0.437123
# Epoch: 22 	Training Loss: 0.432521 	Validation Loss: 0.444854
# Epoch: 23 	Training Loss: 0.431922 	Validation Loss: 0.431607
# Epoch: 24 	Training Loss: 0.432330 	Validation Loss: 0.447336
# Epoch: 25 	Training Loss: 0.431412 	Validation Loss: 0.433769
# Epoch: 26 	Training Loss: 0.431295 	Validation Loss: 0.430062
# Epoch: 27 	Training Loss: 0.432480 	Validation Loss: 0.435669
# Epoch: 28 	Training Loss: 0.431006 	Validation Loss: 0.438602
# Epoch: 29 	Training Loss: 0.429888 	Validation Loss: 0.439639
# Epoch: 30 	Training Loss: 0.430106 	Validation Loss: 0.432763
# Epoch: 31 	Training Loss: 0.429874 	Validation Loss: 0.434119
# Epoch: 32 	Training Loss: 0.429201 	Validation Loss: 0.447959
# Epoch: 33 	Training Loss: 0.429093 	Validation Loss: 0.432080
# Epoch: 34 	Training Loss: 0.428991 	Validation Loss: 0.441853
# Epoch: 35 	Training Loss: 0.430059 	Validation Loss: 0.440408
# Epoch: 36 	Training Loss: 0.428576 	Validation Loss: 0.425148
# Validation loss decreased (0.427180 --> 0.425148).  Saving model ...
# Epoch: 37 	Training Loss: 0.430166 	Validation Loss: 0.434842
# Epoch: 38 	Training Loss: 0.428849 	Validation Loss: 0.434269
# Epoch: 39 	Training Loss: 0.428221 	Validation Loss: 0.436912
# Epoch: 40 	Training Loss: 0.429282 	Validation Loss: 0.428729
# Epoch: 41 	Training Loss: 0.428968 	Validation Loss: 0.434052
# Epoch: 42 	Training Loss: 0.428157 	Validation Loss: 0.431640
# Epoch: 43 	Training Loss: 0.427840 	Validation Loss: 0.430411
# Epoch: 44 	Training Loss: 0.428057 	Validation Loss: 0.428386
# Epoch: 45 	Training Loss: 0.427326 	Validation Loss: 0.431797
# Epoch: 46 	Training Loss: 0.427231 	Validation Loss: 0.428883
# Epoch: 47 	Training Loss: 0.427921 	Validation Loss: 0.428936
# Epoch: 48 	Training Loss: 0.427105 	Validation Loss: 0.432412
# Epoch: 49 	Training Loss: 0.427715 	Validation Loss: 0.430132
# Epoch: 50 	Training Loss: 0.426797 	Validation Loss: 0.429283
# Epoch: 51 	Training Loss: 0.427152 	Validation Loss: 0.428085
# Epoch: 52 	Training Loss: 0.426908 	Validation Loss: 0.426722
# Epoch: 53 	Training Loss: 0.427371 	Validation Loss: 0.434182
# Epoch: 54 	Training Loss: 0.426815 	Validation Loss: 0.433866
# Epoch: 55 	Training Loss: 0.426132 	Validation Loss: 0.426177
# Epoch: 56 	Training Loss: 0.426679 	Validation Loss: 0.427709
# Epoch: 57 	Training Loss: 0.425853 	Validation Loss: 0.430812
# Epoch: 58 	Training Loss: 0.426518 	Validation Loss: 0.431926
# Epoch: 59 	Training Loss: 0.425871 	Validation Loss: 0.428040
# Epoch: 60 	Training Loss: 0.427165 	Validation Loss: 0.431243
# Epoch: 61 	Training Loss: 0.426107 	Validation Loss: 0.430295
# Epoch: 62 	Training Loss: 0.426930 	Validation Loss: 0.430526
# Epoch: 63 	Training Loss: 0.426661 	Validation Loss: 0.435678
# Epoch: 64 	Training Loss: 0.425733 	Validation Loss: 0.428389
# Epoch: 65 	Training Loss: 0.426346 	Validation Loss: 0.430907
# Epoch: 66 	Training Loss: 0.426744 	Validation Loss: 0.429715
# Epoch: 67 	Training Loss: 0.426152 	Validation Loss: 0.425701
# Epoch: 68 	Training Loss: 0.425483 	Validation Loss: 0.425696
# Epoch: 69 	Training Loss: 0.426128 	Validation Loss: 0.424743
# Validation loss decreased (0.425148 --> 0.424743).  Saving model ...
# Epoch: 70 	Training Loss: 0.426595 	Validation Loss: 0.434426
# Epoch: 71 	Training Loss: 0.425639 	Validation Loss: 0.427167
# Epoch: 72 	Training Loss: 0.425673 	Validation Loss: 0.424346
# Validation loss decreased (0.424743 --> 0.424346).  Saving model ...
# Epoch: 73 	Training Loss: 0.425643 	Validation Loss: 0.428308
# Epoch: 74 	Training Loss: 0.425899 	Validation Loss: 0.425843
# Epoch: 75 	Training Loss: 0.425744 	Validation Loss: 0.427593
# Epoch: 76 	Training Loss: 0.426184 	Validation Loss: 0.427604
# Epoch: 77 	Training Loss: 0.424891 	Validation Loss: 0.429720
# Epoch: 78 	Training Loss: 0.425510 	Validation Loss: 0.428373
# Epoch: 79 	Training Loss: 0.426762 	Validation Loss: 0.426853
# Epoch: 80 	Training Loss: 0.424863 	Validation Loss: 0.426668
# Epoch: 81 	Training Loss: 0.425260 	Validation Loss: 0.430016
# Epoch: 82 	Training Loss: 0.425328 	Validation Loss: 0.428464
# Epoch: 83 	Training Loss: 0.425636 	Validation Loss: 0.430030
# Epoch: 84 	Training Loss: 0.425723 	Validation Loss: 0.430313
# Epoch: 85 	Training Loss: 0.425492 	Validation Loss: 0.424673
# Epoch: 86 	Training Loss: 0.424751 	Validation Loss: 0.424294
# Validation loss decreased (0.424346 --> 0.424294).  Saving model ...
# Epoch: 87 	Training Loss: 0.425388 	Validation Loss: 0.431254
# Epoch: 88 	Training Loss: 0.425522 	Validation Loss: 0.430454
# Epoch: 89 	Training Loss: 0.425266 	Validation Loss: 0.430326
# Epoch: 90 	Training Loss: 0.425435 	Validation Loss: 0.426097
# Epoch: 91 	Training Loss: 0.424642 	Validation Loss: 0.424828
# Epoch: 92 	Training Loss: 0.425414 	Validation Loss: 0.429430
# Epoch: 93 	Training Loss: 0.424485 	Validation Loss: 0.426440
# Epoch: 94 	Training Loss: 0.425471 	Validation Loss: 0.423702
# Validation loss decreased (0.424294 --> 0.423702).  Saving model ...
# Epoch: 95 	Training Loss: 0.425153 	Validation Loss: 0.423508
# Validation loss decreased (0.423702 --> 0.423508).  Saving model ...
# Epoch: 96 	Training Loss: 0.425426 	Validation Loss: 0.428534
# Epoch: 97 	Training Loss: 0.424702 	Validation Loss: 0.433104
# Epoch: 98 	Training Loss: 0.424944 	Validation Loss: 0.425800
# Epoch: 99 	Training Loss: 0.425603 	Validation Loss: 0.427077
# Epoch: 100 	Training Loss: 0.425136 	Validation Loss: 0.426486
# Epoch: 101 	Training Loss: 0.424225 	Validation Loss: 0.426430
# Epoch: 102 	Training Loss: 0.424499 	Validation Loss: 0.422971
# Validation loss decreased (0.423508 --> 0.422971).  Saving model ...
# Epoch: 103 	Training Loss: 0.425566 	Validation Loss: 0.423658
# Epoch: 104 	Training Loss: 0.424866 	Validation Loss: 0.425780
# Epoch: 105 	Training Loss: 0.423904 	Validation Loss: 0.424040
# Epoch: 106 	Training Loss: 0.424515 	Validation Loss: 0.426283
# Epoch: 107 	Training Loss: 0.424402 	Validation Loss: 0.426597
# Epoch: 108 	Training Loss: 0.425269 	Validation Loss: 0.424351
# Epoch: 109 	Training Loss: 0.425376 	Validation Loss: 0.425778
# Epoch: 110 	Training Loss: 0.425088 	Validation Loss: 0.423115
# Epoch: 111 	Training Loss: 0.425450 	Validation Loss: 0.427575
# Epoch: 112 	Training Loss: 0.424736 	Validation Loss: 0.431179
# Epoch: 113 	Training Loss: 0.424083 	Validation Loss: 0.429580
# Epoch: 114 	Training Loss: 0.424550 	Validation Loss: 0.427412
# Epoch: 115 	Training Loss: 0.424974 	Validation Loss: 0.427031
# Epoch: 116 	Training Loss: 0.424325 	Validation Loss: 0.427262
# Epoch: 117 	Training Loss: 0.424829 	Validation Loss: 0.428456
# Epoch: 118 	Training Loss: 0.424081 	Validation Loss: 0.426278
# Epoch: 119 	Training Loss: 0.424235 	Validation Loss: 0.426763
# Epoch: 120 	Training Loss: 0.424837 	Validation Loss: 0.427798
# Epoch: 121 	Training Loss: 0.424229 	Validation Loss: 0.427089
# Epoch: 122 	Training Loss: 0.424750 	Validation Loss: 0.426655
# Epoch: 123 	Training Loss: 0.424652 	Validation Loss: 0.423782
# Epoch: 124 	Training Loss: 0.424211 	Validation Loss: 0.432574
# Epoch: 125 	Training Loss: 0.424616 	Validation Loss: 0.425706
# Epoch: 126 	Training Loss: 0.423989 	Validation Loss: 0.425734
# Epoch: 127 	Training Loss: 0.424114 	Validation Loss: 0.426782
# Epoch: 128 	Training Loss: 0.424604 	Validation Loss: 0.425071
# Epoch: 129 	Training Loss: 0.424410 	Validation Loss: 0.424708
# Epoch: 130 	Training Loss: 0.424775 	Validation Loss: 0.428352
# Epoch: 131 	Training Loss: 0.424125 	Validation Loss: 0.425200
# Epoch: 132 	Training Loss: 0.424484 	Validation Loss: 0.427708
# Epoch: 133 	Training Loss: 0.424681 	Validation Loss: 0.424508
# Epoch: 134 	Training Loss: 0.424074 	Validation Loss: 0.432063
# Epoch: 135 	Training Loss: 0.424672 	Validation Loss: 0.423766
# Epoch: 136 	Training Loss: 0.424089 	Validation Loss: 0.429597
# Epoch: 137 	Training Loss: 0.423800 	Validation Loss: 0.425781
# Epoch: 138 	Training Loss: 0.424352 	Validation Loss: 0.428953
# Epoch: 139 	Training Loss: 0.424785 	Validation Loss: 0.426124
# Epoch: 140 	Training Loss: 0.424566 	Validation Loss: 0.422573
# Validation loss decreased (0.422971 --> 0.422573).  Saving model ...
# Epoch: 141 	Training Loss: 0.424964 	Validation Loss: 0.425485
# Epoch: 142 	Training Loss: 0.424321 	Validation Loss: 0.423544
# Epoch: 143 	Training Loss: 0.424356 	Validation Loss: 0.425372
# Epoch: 144 	Training Loss: 0.424281 	Validation Loss: 0.425471
# Epoch: 145 	Training Loss: 0.424236 	Validation Loss: 0.428681
# Epoch: 146 	Training Loss: 0.424840 	Validation Loss: 0.429461
# Epoch: 147 	Training Loss: 0.424197 	Validation Loss: 0.427522
# Epoch: 148 	Training Loss: 0.425035 	Validation Loss: 0.423781
# Epoch: 149 	Training Loss: 0.424009 	Validation Loss: 0.428243
# Epoch: 150 	Training Loss: 0.424709 	Validation Loss: 0.425687
# Epoch: 151 	Training Loss: 0.424983 	Validation Loss: 0.425757
# Epoch: 152 	Training Loss: 0.423607 	Validation Loss: 0.426687
# Epoch: 153 	Training Loss: 0.425435 	Validation Loss: 0.426048
# Epoch: 154 	Training Loss: 0.424836 	Validation Loss: 0.426189
# Epoch: 155 	Training Loss: 0.424939 	Validation Loss: 0.426814
# Epoch: 156 	Training Loss: 0.424993 	Validation Loss: 0.425073
# Epoch: 157 	Training Loss: 0.424221 	Validation Loss: 0.425992
# Epoch: 158 	Training Loss: 0.424914 	Validation Loss: 0.429751
# Epoch: 159 	Training Loss: 0.423857 	Validation Loss: 0.423714
# Epoch: 160 	Training Loss: 0.424008 	Validation Loss: 0.428114
# Epoch: 161 	Training Loss: 0.424038 	Validation Loss: 0.425710
# Epoch: 162 	Training Loss: 0.423697 	Validation Loss: 0.425223
# Epoch: 163 	Training Loss: 0.424057 	Validation Loss: 0.426672
# Epoch: 164 	Training Loss: 0.424442 	Validation Loss: 0.428183
# Epoch: 165 	Training Loss: 0.423444 	Validation Loss: 0.425638
# Epoch: 166 	Training Loss: 0.424390 	Validation Loss: 0.424620
# Epoch: 167 	Training Loss: 0.423830 	Validation Loss: 0.428754
# Epoch: 168 	Training Loss: 0.424590 	Validation Loss: 0.428714
# Epoch: 169 	Training Loss: 0.423989 	Validation Loss: 0.435516
# Epoch: 170 	Training Loss: 0.423707 	Validation Loss: 0.432749
# Epoch: 171 	Training Loss: 0.424181 	Validation Loss: 0.426053
# Epoch: 172 	Training Loss: 0.421501 	Validation Loss: 0.424951
# Epoch: 173 	Training Loss: 0.420386 	Validation Loss: 0.422974
# Epoch: 174 	Training Loss: 0.420244 	Validation Loss: 0.420812
# Validation loss decreased (0.422573 --> 0.420812).  Saving model ...
# Epoch: 175 	Training Loss: 0.419299 	Validation Loss: 0.426847
# Epoch: 176 	Training Loss: 0.417780 	Validation Loss: 0.438267
# Epoch: 177 	Training Loss: 0.416193 	Validation Loss: 0.420686
# Validation loss decreased (0.420812 --> 0.420686).  Saving model ...
# Epoch: 178 	Training Loss: 0.416128 	Validation Loss: 0.419282
# Validation loss decreased (0.420686 --> 0.419282).  Saving model ...
# Epoch: 179 	Training Loss: 0.414189 	Validation Loss: 0.421076
# Epoch: 180 	Training Loss: 0.414997 	Validation Loss: 0.425754
# Epoch: 181 	Training Loss: 0.415411 	Validation Loss: 0.430293
# Epoch: 182 	Training Loss: 0.413555 	Validation Loss: 0.418560
# Validation loss decreased (0.419282 --> 0.418560).  Saving model ...
# Epoch: 183 	Training Loss: 0.413166 	Validation Loss: 0.419323
# Epoch: 184 	Training Loss: 0.412726 	Validation Loss: 0.424674
# Epoch: 185 	Training Loss: 0.412914 	Validation Loss: 0.424013
# Epoch: 186 	Training Loss: 0.412910 	Validation Loss: 0.420701
# Epoch: 187 	Training Loss: 0.411233 	Validation Loss: 0.419648
# Epoch: 188 	Training Loss: 0.412303 	Validation Loss: 0.420080
# Epoch: 189 	Training Loss: 0.412130 	Validation Loss: 0.428672
# Epoch: 190 	Training Loss: 0.412937 	Validation Loss: 0.419628
# Epoch: 191 	Training Loss: 0.412797 	Validation Loss: 0.422701
# Epoch: 192 	Training Loss: 0.411849 	Validation Loss: 0.416086
# Validation loss decreased (0.418560 --> 0.416086).  Saving model ...
# Epoch: 193 	Training Loss: 0.411458 	Validation Loss: 0.412861
# Validation loss decreased (0.416086 --> 0.412861).  Saving model ...
# Epoch: 194 	Training Loss: 0.411441 	Validation Loss: 0.421412
# Epoch: 195 	Training Loss: 0.411429 	Validation Loss: 0.423648
# Epoch: 196 	Training Loss: 0.411055 	Validation Loss: 0.407988
# Validation loss decreased (0.412861 --> 0.407988).  Saving model ...
# Epoch: 197 	Training Loss: 0.409897 	Validation Loss: 0.426907
# Epoch: 198 	Training Loss: 0.410423 	Validation Loss: 0.418607
# Epoch: 199 	Training Loss: 0.409896 	Validation Loss: 0.432653
# Epoch: 200 	Training Loss: 0.410096 	Validation Loss: 0.413885
# Epoch: 201 	Training Loss: 0.410819 	Validation Loss: 0.413998
# Epoch: 202 	Training Loss: 0.411348 	Validation Loss: 0.425360
# Epoch: 203 	Training Loss: 0.410072 	Validation Loss: 0.412585
# Epoch: 204 	Training Loss: 0.410609 	Validation Loss: 0.411666
# Epoch: 205 	Training Loss: 0.408502 	Validation Loss: 0.416561
# Epoch: 206 	Training Loss: 0.409676 	Validation Loss: 0.412900
# Epoch: 207 	Training Loss: 0.410185 	Validation Loss: 0.416853
# Epoch: 208 	Training Loss: 0.409114 	Validation Loss: 0.410370
# Epoch: 209 	Training Loss: 0.409593 	Validation Loss: 0.416621
# Epoch: 210 	Training Loss: 0.410015 	Validation Loss: 0.412868
# Epoch: 211 	Training Loss: 0.409519 	Validation Loss: 0.410969
# Epoch: 212 	Training Loss: 0.409423 	Validation Loss: 0.416402
# Epoch: 213 	Training Loss: 0.408672 	Validation Loss: 0.418490
# Epoch: 214 	Training Loss: 0.409966 	Validation Loss: 0.419923
# Epoch: 215 	Training Loss: 0.409376 	Validation Loss: 0.411879
# Epoch: 216 	Training Loss: 0.409599 	Validation Loss: 0.417625
# Epoch: 217 	Training Loss: 0.408980 	Validation Loss: 0.423821
# Epoch: 218 	Training Loss: 0.409543 	Validation Loss: 0.417399
# Epoch: 219 	Training Loss: 0.409025 	Validation Loss: 0.413815
# Epoch: 220 	Training Loss: 0.408805 	Validation Loss: 0.422523
# Epoch: 221 	Training Loss: 0.409330 	Validation Loss: 0.413068
# Epoch: 222 	Training Loss: 0.408507 	Validation Loss: 0.414145
# Epoch: 223 	Training Loss: 0.408188 	Validation Loss: 0.414002
# Epoch: 224 	Training Loss: 0.408814 	Validation Loss: 0.415613
# Epoch: 225 	Training Loss: 0.408616 	Validation Loss: 0.414982
# Epoch: 226 	Training Loss: 0.407738 	Validation Loss: 0.420968
# Epoch: 227 	Training Loss: 0.408214 	Validation Loss: 0.417232
# Epoch: 228 	Training Loss: 0.408344 	Validation Loss: 0.411301
# Epoch: 229 	Training Loss: 0.409009 	Validation Loss: 0.421650
# Epoch: 230 	Training Loss: 0.408367 	Validation Loss: 0.413618
# Epoch: 231 	Training Loss: 0.407587 	Validation Loss: 0.412851
# Epoch: 232 	Training Loss: 0.407976 	Validation Loss: 0.414903
# Epoch: 233 	Training Loss: 0.408287 	Validation Loss: 0.410596
# Epoch: 234 	Training Loss: 0.408246 	Validation Loss: 0.414310
# Epoch: 235 	Training Loss: 0.407945 	Validation Loss: 0.416764
# Epoch: 236 	Training Loss: 0.407161 	Validation Loss: 0.412162
# Epoch: 237 	Training Loss: 0.408019 	Validation Loss: 0.416437
# Epoch: 238 	Training Loss: 0.408517 	Validation Loss: 0.419979
# Epoch: 239 	Training Loss: 0.407706 	Validation Loss: 0.419351
# Epoch: 240 	Training Loss: 0.408989 	Validation Loss: 0.410966
# Epoch: 241 	Training Loss: 0.408621 	Validation Loss: 0.414475
# Epoch: 242 	Training Loss: 0.407268 	Validation Loss: 0.411367
# Epoch: 243 	Training Loss: 0.408366 	Validation Loss: 0.412881
# Epoch: 244 	Training Loss: 0.406994 	Validation Loss: 0.411886
# Epoch: 245 	Training Loss: 0.408775 	Validation Loss: 0.414655
# Epoch: 246 	Training Loss: 0.407370 	Validation Loss: 0.408682
# Epoch: 247 	Training Loss: 0.407779 	Validation Loss: 0.410669
# Epoch: 248 	Training Loss: 0.407305 	Validation Loss: 0.415111
# Epoch: 249 	Training Loss: 0.407578 	Validation Loss: 0.416098
# Epoch: 250 	Training Loss: 0.407119 	Validation Loss: 0.408906
# Epoch: 251 	Training Loss: 0.407586 	Validation Loss: 0.409952
# Epoch: 252 	Training Loss: 0.407355 	Validation Loss: 0.412297
# Epoch: 253 	Training Loss: 0.406864 	Validation Loss: 0.414077
# Epoch: 254 	Training Loss: 0.407432 	Validation Loss: 0.416377
# Epoch: 255 	Training Loss: 0.406997 	Validation Loss: 0.419689
# Epoch: 256 	Training Loss: 0.406739 	Validation Loss: 0.417608
# Epoch: 257 	Training Loss: 0.407655 	Validation Loss: 0.416025
# Epoch: 258 	Training Loss: 0.408124 	Validation Loss: 0.407664
# Validation loss decreased (0.407988 --> 0.407664).  Saving model ...
# Epoch: 259 	Training Loss: 0.407435 	Validation Loss: 0.413432
# Epoch: 260 	Training Loss: 0.406881 	Validation Loss: 0.412268
# Epoch: 261 	Training Loss: 0.408465 	Validation Loss: 0.416547
# Epoch: 262 	Training Loss: 0.407782 	Validation Loss: 0.415225
# Epoch: 263 	Training Loss: 0.408662 	Validation Loss: 0.415035
# Epoch: 264 	Training Loss: 0.406834 	Validation Loss: 0.414487
# Epoch: 265 	Training Loss: 0.406958 	Validation Loss: 0.415969
# Epoch: 266 	Training Loss: 0.407328 	Validation Loss: 0.414887
# Epoch: 267 	Training Loss: 0.407539 	Validation Loss: 0.409882
# Epoch: 268 	Training Loss: 0.408307 	Validation Loss: 0.409328
# Epoch: 269 	Training Loss: 0.407347 	Validation Loss: 0.422064
# Epoch: 270 	Training Loss: 0.406202 	Validation Loss: 0.414316
# Epoch: 271 	Training Loss: 0.407358 	Validation Loss: 0.414064
# Epoch: 272 	Training Loss: 0.407511 	Validation Loss: 0.409619
# Epoch: 273 	Training Loss: 0.407646 	Validation Loss: 0.412074
# Epoch: 274 	Training Loss: 0.407809 	Validation Loss: 0.414634
# Epoch: 275 	Training Loss: 0.407127 	Validation Loss: 0.412405
# Epoch: 276 	Training Loss: 0.407793 	Validation Loss: 0.411449
# Epoch: 277 	Training Loss: 0.407539 	Validation Loss: 0.409800
# Epoch: 278 	Training Loss: 0.407799 	Validation Loss: 0.409218
# Epoch: 279 	Training Loss: 0.407143 	Validation Loss: 0.411647
# Epoch: 280 	Training Loss: 0.406723 	Validation Loss: 0.417090
# Epoch: 281 	Training Loss: 0.408296 	Validation Loss: 0.416685
# Epoch: 282 	Training Loss: 0.408139 	Validation Loss: 0.423764
# Epoch: 283 	Training Loss: 0.406860 	Validation Loss: 0.412686
# Epoch: 284 	Training Loss: 0.406557 	Validation Loss: 0.416244
# Epoch: 285 	Training Loss: 0.406312 	Validation Loss: 0.411739
# Epoch: 286 	Training Loss: 0.408107 	Validation Loss: 0.415586
# Epoch: 287 	Training Loss: 0.407156 	Validation Loss: 0.405834
# Validation loss decreased (0.407664 --> 0.405834).  Saving model ...
# Epoch: 288 	Training Loss: 0.407496 	Validation Loss: 0.411785
# Epoch: 289 	Training Loss: 0.405434 	Validation Loss: 0.411881
# Epoch: 290 	Training Loss: 0.406636 	Validation Loss: 0.415623
# Epoch: 291 	Training Loss: 0.407717 	Validation Loss: 0.420985
# Epoch: 292 	Training Loss: 0.406841 	Validation Loss: 0.418049
# Epoch: 293 	Training Loss: 0.407347 	Validation Loss: 0.410939
# Epoch: 294 	Training Loss: 0.407494 	Validation Loss: 0.418233
# Epoch: 295 	Training Loss: 0.406425 	Validation Loss: 0.425509
# Epoch: 296 	Training Loss: 0.406173 	Validation Loss: 0.415476
# Epoch: 297 	Training Loss: 0.406666 	Validation Loss: 0.408167
# Epoch: 298 	Training Loss: 0.405255 	Validation Loss: 0.419294
# Epoch: 299 	Training Loss: 0.406849 	Validation Loss: 0.416978
# Epoch: 300 	Training Loss: 0.407373 	Validation Loss: 0.410701
# Training Complete!
# <All keys matched successfully>

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.legend(frameon=False)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

def calcROC(model, X, y):
  ''' Compute Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores. '''

  print('ROC AUC Score:',roc_auc_score(y, model.predict_proba(X)[:, 1]))

  plot_roc_curve(model, X, y)  
  plt.show()

# %%
def test(loaders, model, criterion, use_cuda):
    
    print("Begin Test!")
    
    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.
    
    y_pred_list = []
    target_list = []
    y_true = []
    y_pred = []

    model.eval()
    with torch.no_grad():
      for batch_idx, (data, target) in enumerate(loaders['test']):
          # move to GPU
          if use_cuda:
              data, target = data.cuda(), target.cuda()
          # forward pass: compute predicted outputs by passing inputs to the model
          output = model(data)
          output = output.view(-1)
          target = target.unsqueeze(0).view(-1)
          target_list.append(target.cpu().numpy())
          # calculate the loss
          loss = criterion(output, target)
          # update average test loss 
          test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
          # convert output probabilities to predicted class
          #plt.plot(torch.sigmoid(output.data))
          pred = torch.round(torch.sigmoid(output.data))
          y_pred_list.append(pred.cpu().numpy())
          y_pred.append(output.data.cpu().numpy())
          #pred = output.data.max(1, keepdim=True)[1]
          # compare predictions to true label
          correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
          total += data.size(0)

    y_pred_list = [item for sublist in y_pred_list for item in sublist]
    target_list = [item for sublist in target_list for item in sublist]

    fpr, tpr, thresholds = roc_curve(target_list, y_pred_list)
    roc_auc = auc(fpr, tpr)

    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (100. * correct / total, correct, total))

    print('\nConfusion Matrix:\n')
    print(confusion_matrix(target_list, y_pred_list))

    print('\nClassification Report:\n')
    print(classification_report(target_list, y_pred_list))

    # Calculate the ROC Curve and AUC score for the DNN Classifier
    print('\nROC AUC Score:\n')
    print(roc_auc_score(target_list, y_pred_list))

    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
# call test function    
test(loaders, model, criterion, use_cuda)
# Out:
# Begin Test!
# Test Loss: 0.407440
#
#
# Test Accuracy: 80% (10715/13301)
#
# Confusion Matrix:
#
# [[2196 1250]
#  [1336 8519]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.64      0.63      3446
#          1.0       0.87      0.86      0.87      9855
#
#     accuracy                           0.81     13301
#    macro avg       0.75      0.75      0.75     13301
# weighted avg       0.81      0.81      0.81     13301
#
#
# ROC AUC Score:
#
# 0.7508474446508618

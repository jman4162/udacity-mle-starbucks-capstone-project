# %%
import pandas as pd
import numpy as np
import math
import json
% matplotlib inline

from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

filePath = "/content/drive/My Drive/Udacity-MLE-Capstone-Starbucks-data/"

# read in the json files
#portfolio = pd.read_json(filePath+'data/portfolio.json', orient='records', lines=True)
#profile = pd.read_json(filePath+'data/profile.json', orient='records', lines=True)
#transcript = pd.read_json(filePath+'data/transcript.json', orient='records', lines=True)

predictOfferViewed = 0

if predictOfferViewed:
  # Load data for training
  X = pd.read_pickle(filePath+'dataViewedX.pkl')
  Y = pd.read_pickle(filePath+'dataViewedY.pkl')
else:
  # Load data for training
  X = pd.read_pickle(filePath+'dataX.pkl')
  Y = pd.read_pickle(filePath+'dataY.pkl')

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# setting up torch device:
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('GPU is available.' if torch.cuda.is_available() else 'GPU is NOT avaliable, using CPU.')
# Out:
# GPU is available.

# %% [markdown]
# # Prepare and Split Data

# %%
Y
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 66496    0
# 66497    0
# 66498    0
# 66499    1
# 66500    1
# Name: offer_completed, Length: 66501, dtype: int64

# %%
X
# Out:
#        difficulty  duration  reward  ...  gender_F  gender_M  gender_O
# 0             0.5  0.571429     1.0  ...         0         1         0
# 1             0.5  0.571429     1.0  ...         0         1         0
# 2             0.0  0.142857     0.0  ...         0         1         0
# 3             1.0  1.000000     0.5  ...         0         1         0
# 4             1.0  1.000000     0.5  ...         0         1         0
# ...           ...       ...     ...  ...       ...       ...       ...
# 66496         0.5  0.571429     0.2  ...         1         0         0
# 66497         0.5  0.571429     0.2  ...         1         0         0
# 66498         0.5  0.571429     0.2  ...         1         0         0
# 66499         0.5  0.571429     0.2  ...         0         1         0
# 66500         0.5  0.571429     0.2  ...         0         1         0
#
# [66501 rows x 17 columns]

# %%
# Print columns used as model features
print(X.columns)
# Out:
# Index(['difficulty', 'duration', 'reward', 'chan_social', 'chan_email',
#        'chan_web', 'chan_mobile', 'offer_type_bogo', 'offer_type_discount',
#        'offer_type_informational', 'age', 'income', 'joinDate_month',
#        'joinDate_year', 'gender_F', 'gender_M', 'gender_O'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = preprocessing.MinMaxScaler()
X = min_max_scaler.fit_transform(X)

# We split the dataset into 2/3 training and 1/3 testing sets.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)

# Then we split the training set further into 2/3 training and 1/3 validation sets.
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, shuffle=True)

# %%
print(X_train)
print(X_train.shape)
# Out:
# [[0.25       0.28571429 0.5        ... 0.         1.         0.        ]
#  [0.5        0.57142857 0.2        ... 1.         0.         0.        ]
#  [0.5        0.57142857 1.         ... 1.         0.         0.        ]
#  ...
#  [0.5        1.         0.2        ... 0.         1.         0.        ]
#  [0.5        0.28571429 1.         ... 1.         0.         0.        ]
#  [0.35       0.57142857 0.3        ... 1.         0.         0.        ]]
# (42560, 17)

# %%
print(Y_train)
print(Y_train.shape)
# Out:
# 57458    1
# 21338    1
# 25575    0
# 4937     1
# 51035    0
#         ..
# 1450     1
# 10124    0
# 16299    1
# 26090    1
# 17984    1
# Name: offer_completed, Length: 42560, dtype: int64
# (42560,)

# %%
#test_tensor = torch.Tensor(X.values)

# Convert data into torch.Tensor:
X_train = torch.Tensor(X_train).to(device)
X_val = torch.Tensor(X_val).to(device)
X_test = torch.Tensor(X_test).to(device)

Y_train = torch.Tensor(Y_train.values).to(device)
Y_val = torch.Tensor(Y_val.values).to(device)
Y_test = torch.Tensor(Y_test.values).to(device)

# Create datasets for the dataloaders:
train_data = TensorDataset(X_train, Y_train)
test_data = TensorDataset(X_test, Y_test)
val_data = TensorDataset(X_val, Y_val)

# print out some data stats
print('# of training samples: ', len(train_data))
print('# of validation samples: ', len(val_data))
print('# of test samples: ', len(test_data))

batch_size = 64

# Creating the data loaders:
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)

loaders = {
    'train': train_loader,
    'valid': val_loader,
    'test': test_loader
}
# Out:
# # of training samples:  42560
# # of validation samples:  10640
# # of test samples:  13301

# %%
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# torch.Size([42560, 17]) torch.Size([42560])
# torch.Size([13301, 17]) torch.Size([13301])

# %%
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

n_classes = 1 # Number of classes
n_features = 17 # Number of features

# define the DNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self, n_features):
        super(Net, self).__init__()
        ## Define layers of a DNN
        
        self.fc1 = nn.Linear(n_features, 32)
        # linear layer (17 -> 32)
        self.fc2 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc3 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc4 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc5 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc6 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc7 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc8 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc9 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc10 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc11 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc12 = nn.Linear(32, 32)
        # linear layer (32 -> 32)
        self.fc13 = nn.Linear(32, 32)
        # linear layer (32 -> 16)
        self.fc14 = nn.Linear(32, 16)
        # linear layer (16 -> 8)
        self.fc15 = nn.Linear(16, 8)
        # linear layer (8 -> 1)
        self.fc16 = nn.Linear(8, n_classes)
        
        # dropout layer (p=0.25)
        self.dropout = nn.Dropout(0.25)
    
    def forward(self, x):
        ## Define forward behavior
        
        # add 1st hidden layer, with relu activation function
        x = F.leaky_relu(self.fc1(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc2(x))
        
        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc3(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc4(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc5(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc6(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc7(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc8(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc9(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc10(x))

        #print("a4: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 3rd hidden layer
        x = F.leaky_relu(self.fc11(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc12(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc13(x))

        #print("a3: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = F.leaky_relu(self.fc14(x))

        #print("a4: ",x.shape)
        # add dropout layer
        x = self.dropout(x)
        # add 3rd hidden layer
        x = F.leaky_relu(self.fc15(x))

        #print("a4: ",x.shape)
        # add dropout layer
        #x = self.dropout(x)
        # add 3rd hidden layer
        x = self.fc16(x)

        #print("a5: ",x.shape)
        
        return x
    

# instantiate the CNN
model = Net(n_features)
print(model)

# move tensors to GPU if CUDA is available
if use_cuda:
    model.cuda()
# Out:
# Net(
#   (fc1): Linear(in_features=17, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=32, bias=True)
#   (fc6): Linear(in_features=32, out_features=32, bias=True)
#   (fc7): Linear(in_features=32, out_features=32, bias=True)
#   (fc8): Linear(in_features=32, out_features=32, bias=True)
#   (fc9): Linear(in_features=32, out_features=32, bias=True)
#   (fc10): Linear(in_features=32, out_features=32, bias=True)
#   (fc11): Linear(in_features=32, out_features=32, bias=True)
#   (fc12): Linear(in_features=32, out_features=32, bias=True)
#   (fc13): Linear(in_features=32, out_features=32, bias=True)
#   (fc14): Linear(in_features=32, out_features=16, bias=True)
#   (fc15): Linear(in_features=16, out_features=8, bias=True)
#   (fc16): Linear(in_features=8, out_features=1, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )

# %%
from torch import optim

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    print("Begin training...")
    
    train_losses, valid_losses = [], []
    for epoch in range(1, n_epochs+1):
        #print("Epoch: ",epoch)
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            #if batch_idx % 100 == 0:
                #print("Epoch: {}, Batch: {}".format(epoch,batch_idx))
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            # clear the gradients of all optimized variables
            optimizer.zero_grad()

            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            output = output.view(-1)
            target = target.unsqueeze(0).view(-1)

            # calculate the batch loss
            loss = criterion(output, target)
            
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            
            # perform a single optimization step (parameter update)
            optimizer.step()
            
            # record the average training loss, using something like
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
        ######################    
        # validate the model #
        ######################
        with torch.no_grad():
          model.eval()
          for batch_idx, (data, target) in enumerate(loaders['valid']):
              # move to GPU
              if use_cuda:
                  data, target = data.cuda(), target.cuda()
              ## update the average validation loss

              # forward pass: compute predicted outputs by passing inputs to the model
              output = model(data)
              #output = outputs.view(1, -1)  # make it the same shape as output
              target = target.unsqueeze(0).view(-1)
              output = output.view(-1)

              # calculate the batch loss
              loss = criterion(output, target)
              
              # update average validation loss 
              valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))

        train_losses.append(train_loss)
        valid_losses.append(valid_loss)

        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min, valid_loss))
                
            valid_loss_min = valid_loss
    
    print("Training Complete!")
    # return trained model
    return model, train_losses, valid_losses

# %%
n_epochs = 300 # Number of training epochs

# train the model
model, train_losses, valid_losses = train(n_epochs, loaders, model, optimizer, 
                                          criterion, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# Begin training...
# Epoch: 1 	Training Loss: 0.573564 	Validation Loss: 0.537920
# Validation loss decreased (inf --> 0.537920).  Saving model ...
# Epoch: 2 	Training Loss: 0.535183 	Validation Loss: 0.529537
# Validation loss decreased (0.537920 --> 0.529537).  Saving model ...
# Epoch: 3 	Training Loss: 0.514543 	Validation Loss: 0.500754
# Validation loss decreased (0.529537 --> 0.500754).  Saving model ...
# Epoch: 4 	Training Loss: 0.500594 	Validation Loss: 0.489475
# Validation loss decreased (0.500754 --> 0.489475).  Saving model ...
# Epoch: 5 	Training Loss: 0.490948 	Validation Loss: 0.482810
# Validation loss decreased (0.489475 --> 0.482810).  Saving model ...
# Epoch: 6 	Training Loss: 0.487868 	Validation Loss: 0.477274
# Validation loss decreased (0.482810 --> 0.477274).  Saving model ...
# Epoch: 7 	Training Loss: 0.481773 	Validation Loss: 0.470996
# Validation loss decreased (0.477274 --> 0.470996).  Saving model ...
# Epoch: 8 	Training Loss: 0.480271 	Validation Loss: 0.463141
# Validation loss decreased (0.470996 --> 0.463141).  Saving model ...
# Epoch: 9 	Training Loss: 0.476183 	Validation Loss: 0.461967
# Validation loss decreased (0.463141 --> 0.461967).  Saving model ...
# Epoch: 10 	Training Loss: 0.472116 	Validation Loss: 0.457976
# Validation loss decreased (0.461967 --> 0.457976).  Saving model ...
# Epoch: 11 	Training Loss: 0.468406 	Validation Loss: 0.454516
# Validation loss decreased (0.457976 --> 0.454516).  Saving model ...
# Epoch: 12 	Training Loss: 0.466980 	Validation Loss: 0.450949
# Validation loss decreased (0.454516 --> 0.450949).  Saving model ...
# Epoch: 13 	Training Loss: 0.464817 	Validation Loss: 0.453164
# Epoch: 14 	Training Loss: 0.463477 	Validation Loss: 0.452795
# Epoch: 15 	Training Loss: 0.462282 	Validation Loss: 0.455128
# Epoch: 16 	Training Loss: 0.460462 	Validation Loss: 0.448387
# Validation loss decreased (0.450949 --> 0.448387).  Saving model ...
# Epoch: 17 	Training Loss: 0.458820 	Validation Loss: 0.449961
# Epoch: 18 	Training Loss: 0.460799 	Validation Loss: 0.445085
# Validation loss decreased (0.448387 --> 0.445085).  Saving model ...
# Epoch: 19 	Training Loss: 0.458143 	Validation Loss: 0.443895
# Validation loss decreased (0.445085 --> 0.443895).  Saving model ...
# Epoch: 20 	Training Loss: 0.458876 	Validation Loss: 0.451272
# Epoch: 21 	Training Loss: 0.456001 	Validation Loss: 0.446996
# Epoch: 22 	Training Loss: 0.455833 	Validation Loss: 0.446347
# Epoch: 23 	Training Loss: 0.455443 	Validation Loss: 0.444558
# Epoch: 24 	Training Loss: 0.458006 	Validation Loss: 0.443595
# Validation loss decreased (0.443895 --> 0.443595).  Saving model ...
# Epoch: 25 	Training Loss: 0.457215 	Validation Loss: 0.443557
# Validation loss decreased (0.443595 --> 0.443557).  Saving model ...
# Epoch: 26 	Training Loss: 0.455345 	Validation Loss: 0.445003
# Epoch: 27 	Training Loss: 0.453795 	Validation Loss: 0.447854
# Epoch: 28 	Training Loss: 0.452854 	Validation Loss: 0.442861
# Validation loss decreased (0.443557 --> 0.442861).  Saving model ...
# Epoch: 29 	Training Loss: 0.453245 	Validation Loss: 0.445528
# Epoch: 30 	Training Loss: 0.453915 	Validation Loss: 0.442778
# Validation loss decreased (0.442861 --> 0.442778).  Saving model ...
# Epoch: 31 	Training Loss: 0.454205 	Validation Loss: 0.447340
# Epoch: 32 	Training Loss: 0.452015 	Validation Loss: 0.450111
# Epoch: 33 	Training Loss: 0.454314 	Validation Loss: 0.449826
# Epoch: 34 	Training Loss: 0.454066 	Validation Loss: 0.444298
# Epoch: 35 	Training Loss: 0.454043 	Validation Loss: 0.444727
# Epoch: 36 	Training Loss: 0.455887 	Validation Loss: 0.441620
# Validation loss decreased (0.442778 --> 0.441620).  Saving model ...
# Epoch: 37 	Training Loss: 0.453844 	Validation Loss: 0.445484
# Epoch: 38 	Training Loss: 0.454151 	Validation Loss: 0.445866
# Epoch: 39 	Training Loss: 0.453160 	Validation Loss: 0.448626
# Epoch: 40 	Training Loss: 0.452651 	Validation Loss: 0.442861
# Epoch: 41 	Training Loss: 0.451687 	Validation Loss: 0.442619
# Epoch: 42 	Training Loss: 0.451168 	Validation Loss: 0.443144
# Epoch: 43 	Training Loss: 0.451507 	Validation Loss: 0.441779
# Epoch: 44 	Training Loss: 0.451784 	Validation Loss: 0.441768
# Epoch: 45 	Training Loss: 0.451169 	Validation Loss: 0.440743
# Validation loss decreased (0.441620 --> 0.440743).  Saving model ...
# Epoch: 46 	Training Loss: 0.452256 	Validation Loss: 0.444092
# Epoch: 47 	Training Loss: 0.451082 	Validation Loss: 0.440983
# Epoch: 48 	Training Loss: 0.451467 	Validation Loss: 0.443992
# Epoch: 49 	Training Loss: 0.450940 	Validation Loss: 0.445482
# Epoch: 50 	Training Loss: 0.451614 	Validation Loss: 0.450711
# Epoch: 51 	Training Loss: 0.451375 	Validation Loss: 0.453403
# Epoch: 52 	Training Loss: 0.449778 	Validation Loss: 0.444380
# Epoch: 53 	Training Loss: 0.451376 	Validation Loss: 0.443609
# Epoch: 54 	Training Loss: 0.450919 	Validation Loss: 0.447495
# Epoch: 55 	Training Loss: 0.453596 	Validation Loss: 0.442441
# Epoch: 56 	Training Loss: 0.451308 	Validation Loss: 0.441000
# Epoch: 57 	Training Loss: 0.450933 	Validation Loss: 0.441979
# Epoch: 58 	Training Loss: 0.454605 	Validation Loss: 0.444014
# Epoch: 59 	Training Loss: 0.452130 	Validation Loss: 0.441799
# Epoch: 60 	Training Loss: 0.453395 	Validation Loss: 0.443419
# Epoch: 61 	Training Loss: 0.453643 	Validation Loss: 0.444982
# Epoch: 62 	Training Loss: 0.450148 	Validation Loss: 0.445475
# Epoch: 63 	Training Loss: 0.453913 	Validation Loss: 0.446795
# Epoch: 64 	Training Loss: 0.457478 	Validation Loss: 0.443862
# Epoch: 65 	Training Loss: 0.454022 	Validation Loss: 0.448360
# Epoch: 66 	Training Loss: 0.457023 	Validation Loss: 0.453853
# Epoch: 67 	Training Loss: 0.453056 	Validation Loss: 0.469845
# Epoch: 68 	Training Loss: 0.454766 	Validation Loss: 0.456412
# Epoch: 69 	Training Loss: 0.456415 	Validation Loss: 0.457986
# Epoch: 70 	Training Loss: 0.462672 	Validation Loss: 0.454531
# Epoch: 71 	Training Loss: 0.455732 	Validation Loss: 0.442224
# Epoch: 72 	Training Loss: 0.455005 	Validation Loss: 0.452225
# Epoch: 73 	Training Loss: 0.457653 	Validation Loss: 0.450589
# Epoch: 74 	Training Loss: 0.453755 	Validation Loss: 0.444467
# Epoch: 75 	Training Loss: 0.452583 	Validation Loss: 0.440955
# Epoch: 76 	Training Loss: 0.450477 	Validation Loss: 0.445526
# Epoch: 77 	Training Loss: 0.450514 	Validation Loss: 0.448291
# Epoch: 78 	Training Loss: 0.450964 	Validation Loss: 0.450545
# Epoch: 79 	Training Loss: 0.450770 	Validation Loss: 0.440993
# Epoch: 80 	Training Loss: 0.452518 	Validation Loss: 0.444932
# Epoch: 81 	Training Loss: 0.451170 	Validation Loss: 0.441400
# Epoch: 82 	Training Loss: 0.447943 	Validation Loss: 0.441090
# Epoch: 83 	Training Loss: 0.450196 	Validation Loss: 0.440455
# Validation loss decreased (0.440743 --> 0.440455).  Saving model ...
# Epoch: 84 	Training Loss: 0.449178 	Validation Loss: 0.440409
# Validation loss decreased (0.440455 --> 0.440409).  Saving model ...
# Epoch: 85 	Training Loss: 0.449861 	Validation Loss: 0.444425
# Epoch: 86 	Training Loss: 0.448296 	Validation Loss: 0.442286
# Epoch: 87 	Training Loss: 0.451707 	Validation Loss: 0.443564
# Epoch: 88 	Training Loss: 0.449764 	Validation Loss: 0.442314
# Epoch: 89 	Training Loss: 0.450159 	Validation Loss: 0.444932
# Epoch: 90 	Training Loss: 0.448477 	Validation Loss: 0.439448
# Validation loss decreased (0.440409 --> 0.439448).  Saving model ...
# Epoch: 91 	Training Loss: 0.450120 	Validation Loss: 0.442113
# Epoch: 92 	Training Loss: 0.453398 	Validation Loss: 0.440542
# Epoch: 93 	Training Loss: 0.448850 	Validation Loss: 0.439148
# Validation loss decreased (0.439448 --> 0.439148).  Saving model ...
# Epoch: 94 	Training Loss: 0.450527 	Validation Loss: 0.449015
# Epoch: 95 	Training Loss: 0.453138 	Validation Loss: 0.443844
# Epoch: 96 	Training Loss: 0.448979 	Validation Loss: 0.442811
# Epoch: 97 	Training Loss: 0.447056 	Validation Loss: 0.440017
# Epoch: 98 	Training Loss: 0.447011 	Validation Loss: 0.439421
# Epoch: 99 	Training Loss: 0.449592 	Validation Loss: 0.445229
# Epoch: 100 	Training Loss: 0.447461 	Validation Loss: 0.442869
# Epoch: 101 	Training Loss: 0.446301 	Validation Loss: 0.442397
# Epoch: 102 	Training Loss: 0.446796 	Validation Loss: 0.442629
# Epoch: 103 	Training Loss: 0.447227 	Validation Loss: 0.439859
# Epoch: 104 	Training Loss: 0.446663 	Validation Loss: 0.448275
# Epoch: 105 	Training Loss: 0.447519 	Validation Loss: 0.437709
# Validation loss decreased (0.439148 --> 0.437709).  Saving model ...
# Epoch: 106 	Training Loss: 0.446934 	Validation Loss: 0.441794
# Epoch: 107 	Training Loss: 0.446628 	Validation Loss: 0.436970
# Validation loss decreased (0.437709 --> 0.436970).  Saving model ...
# Epoch: 108 	Training Loss: 0.446782 	Validation Loss: 0.438388
# Epoch: 109 	Training Loss: 0.446320 	Validation Loss: 0.437016
# Epoch: 110 	Training Loss: 0.449474 	Validation Loss: 0.443582
# Epoch: 111 	Training Loss: 0.446822 	Validation Loss: 0.440715
# Epoch: 112 	Training Loss: 0.450535 	Validation Loss: 0.439696
# Epoch: 113 	Training Loss: 0.447369 	Validation Loss: 0.444086
# Epoch: 114 	Training Loss: 0.449101 	Validation Loss: 0.442968
# Epoch: 115 	Training Loss: 0.446353 	Validation Loss: 0.434842
# Validation loss decreased (0.436970 --> 0.434842).  Saving model ...
# Epoch: 116 	Training Loss: 0.452380 	Validation Loss: 0.446706
# Epoch: 117 	Training Loss: 0.448993 	Validation Loss: 0.439627
# Epoch: 118 	Training Loss: 0.450413 	Validation Loss: 0.438510
# Epoch: 119 	Training Loss: 0.447134 	Validation Loss: 0.441047
# Epoch: 120 	Training Loss: 0.448406 	Validation Loss: 0.446758
# Epoch: 121 	Training Loss: 0.449714 	Validation Loss: 0.445669
# Epoch: 122 	Training Loss: 0.447591 	Validation Loss: 0.440981
# Epoch: 123 	Training Loss: 0.447475 	Validation Loss: 0.440504
# Epoch: 124 	Training Loss: 0.446969 	Validation Loss: 0.444674
# Epoch: 125 	Training Loss: 0.447800 	Validation Loss: 0.443640
# Epoch: 126 	Training Loss: 0.447017 	Validation Loss: 0.437787
# Epoch: 127 	Training Loss: 0.449437 	Validation Loss: 0.440063
# Epoch: 128 	Training Loss: 0.445868 	Validation Loss: 0.442515
# Epoch: 129 	Training Loss: 0.446690 	Validation Loss: 0.442279
# Epoch: 130 	Training Loss: 0.447902 	Validation Loss: 0.437320
# Epoch: 131 	Training Loss: 0.448290 	Validation Loss: 0.441839
# Epoch: 132 	Training Loss: 0.446393 	Validation Loss: 0.438905
# Epoch: 133 	Training Loss: 0.447738 	Validation Loss: 0.439987
# Epoch: 134 	Training Loss: 0.446248 	Validation Loss: 0.443219
# Epoch: 135 	Training Loss: 0.447059 	Validation Loss: 0.442222
# Epoch: 136 	Training Loss: 0.448432 	Validation Loss: 0.447639
# Epoch: 137 	Training Loss: 0.447159 	Validation Loss: 0.442523
# Epoch: 138 	Training Loss: 0.450898 	Validation Loss: 0.441751
# Epoch: 139 	Training Loss: 0.448102 	Validation Loss: 0.436452
# Epoch: 140 	Training Loss: 0.447316 	Validation Loss: 0.440092
# Epoch: 141 	Training Loss: 0.449870 	Validation Loss: 0.453284
# Epoch: 142 	Training Loss: 0.449178 	Validation Loss: 0.444537
# Epoch: 143 	Training Loss: 0.446128 	Validation Loss: 0.438350
# Epoch: 144 	Training Loss: 0.446771 	Validation Loss: 0.446272
# Epoch: 145 	Training Loss: 0.447858 	Validation Loss: 0.438437
# Epoch: 146 	Training Loss: 0.448854 	Validation Loss: 0.442711
# Epoch: 147 	Training Loss: 0.447018 	Validation Loss: 0.443726
# Epoch: 148 	Training Loss: 0.445859 	Validation Loss: 0.439111
# Epoch: 149 	Training Loss: 0.446319 	Validation Loss: 0.442911
# Epoch: 150 	Training Loss: 0.446481 	Validation Loss: 0.445611
# Epoch: 151 	Training Loss: 0.445537 	Validation Loss: 0.442002
# Epoch: 152 	Training Loss: 0.445851 	Validation Loss: 0.447149
# Epoch: 153 	Training Loss: 0.446722 	Validation Loss: 0.440802
# Epoch: 154 	Training Loss: 0.445409 	Validation Loss: 0.442278
# Epoch: 155 	Training Loss: 0.446259 	Validation Loss: 0.439265
# Epoch: 156 	Training Loss: 0.445994 	Validation Loss: 0.439597
# Epoch: 157 	Training Loss: 0.447680 	Validation Loss: 0.442846
# Epoch: 158 	Training Loss: 0.446072 	Validation Loss: 0.436063
# Epoch: 159 	Training Loss: 0.447443 	Validation Loss: 0.446318
# Epoch: 160 	Training Loss: 0.444982 	Validation Loss: 0.438172
# Epoch: 161 	Training Loss: 0.445129 	Validation Loss: 0.446376
# Epoch: 162 	Training Loss: 0.445030 	Validation Loss: 0.441235
# Epoch: 163 	Training Loss: 0.446378 	Validation Loss: 0.443201
# Epoch: 164 	Training Loss: 0.446026 	Validation Loss: 0.439682
# Epoch: 165 	Training Loss: 0.446873 	Validation Loss: 0.437295
# Epoch: 166 	Training Loss: 0.444960 	Validation Loss: 0.441300
# Epoch: 167 	Training Loss: 0.445558 	Validation Loss: 0.439899
# Epoch: 168 	Training Loss: 0.445150 	Validation Loss: 0.444680
# Epoch: 169 	Training Loss: 0.446714 	Validation Loss: 0.438386
# Epoch: 170 	Training Loss: 0.446838 	Validation Loss: 0.440219
# Epoch: 171 	Training Loss: 0.446336 	Validation Loss: 0.440751
# Epoch: 172 	Training Loss: 0.446112 	Validation Loss: 0.445239
# Epoch: 173 	Training Loss: 0.446588 	Validation Loss: 0.439957
# Epoch: 174 	Training Loss: 0.443489 	Validation Loss: 0.441375
# Epoch: 175 	Training Loss: 0.445770 	Validation Loss: 0.439511
# Epoch: 176 	Training Loss: 0.444829 	Validation Loss: 0.439815
# Epoch: 177 	Training Loss: 0.447546 	Validation Loss: 0.437815
# Epoch: 178 	Training Loss: 0.446433 	Validation Loss: 0.437952
# Epoch: 179 	Training Loss: 0.445825 	Validation Loss: 0.439381
# Epoch: 180 	Training Loss: 0.447597 	Validation Loss: 0.441630
# Epoch: 181 	Training Loss: 0.450479 	Validation Loss: 0.440099
# Epoch: 182 	Training Loss: 0.448936 	Validation Loss: 0.442450
# Epoch: 183 	Training Loss: 0.448108 	Validation Loss: 0.437634
# Epoch: 184 	Training Loss: 0.446209 	Validation Loss: 0.437583
# Epoch: 185 	Training Loss: 0.445608 	Validation Loss: 0.436813
# Epoch: 186 	Training Loss: 0.444516 	Validation Loss: 0.438883
# Epoch: 187 	Training Loss: 0.444670 	Validation Loss: 0.443395
# Epoch: 188 	Training Loss: 0.447443 	Validation Loss: 0.439481
# Epoch: 189 	Training Loss: 0.446535 	Validation Loss: 0.437622
# Epoch: 190 	Training Loss: 0.447218 	Validation Loss: 0.445001
# Epoch: 191 	Training Loss: 0.446499 	Validation Loss: 0.443267
# Epoch: 192 	Training Loss: 0.446202 	Validation Loss: 0.444480
# Epoch: 193 	Training Loss: 0.446344 	Validation Loss: 0.445832
# Epoch: 194 	Training Loss: 0.445523 	Validation Loss: 0.439093
# Epoch: 195 	Training Loss: 0.448668 	Validation Loss: 0.446341
# Epoch: 196 	Training Loss: 0.448896 	Validation Loss: 0.443898
# Epoch: 197 	Training Loss: 0.449847 	Validation Loss: 0.452154
# Epoch: 198 	Training Loss: 0.448183 	Validation Loss: 0.449620
# Epoch: 199 	Training Loss: 0.446954 	Validation Loss: 0.442596
# Epoch: 200 	Training Loss: 0.447207 	Validation Loss: 0.443018
# Epoch: 201 	Training Loss: 0.445573 	Validation Loss: 0.441073
# Epoch: 202 	Training Loss: 0.445224 	Validation Loss: 0.444214
# Epoch: 203 	Training Loss: 0.446215 	Validation Loss: 0.443177
# Epoch: 204 	Training Loss: 0.448198 	Validation Loss: 0.442900
# Epoch: 205 	Training Loss: 0.446454 	Validation Loss: 0.438734
# Epoch: 206 	Training Loss: 0.445052 	Validation Loss: 0.439669
# Epoch: 207 	Training Loss: 0.454509 	Validation Loss: 0.446433
# Epoch: 208 	Training Loss: 0.446137 	Validation Loss: 0.441511
# Epoch: 209 	Training Loss: 0.444724 	Validation Loss: 0.443549
# Epoch: 210 	Training Loss: 0.447480 	Validation Loss: 0.444280
# Epoch: 211 	Training Loss: 0.444680 	Validation Loss: 0.438001
# Epoch: 212 	Training Loss: 0.445321 	Validation Loss: 0.440463
# Epoch: 213 	Training Loss: 0.445730 	Validation Loss: 0.444628
# Epoch: 214 	Training Loss: 0.445772 	Validation Loss: 0.438686
# Epoch: 215 	Training Loss: 0.444272 	Validation Loss: 0.440509
# Epoch: 216 	Training Loss: 0.446073 	Validation Loss: 0.449201
# Epoch: 217 	Training Loss: 0.445811 	Validation Loss: 0.444050
# Epoch: 218 	Training Loss: 0.445289 	Validation Loss: 0.443844
# Epoch: 219 	Training Loss: 0.448935 	Validation Loss: 0.451631
# Epoch: 220 	Training Loss: 0.446837 	Validation Loss: 0.441521
# Epoch: 221 	Training Loss: 0.443789 	Validation Loss: 0.443284
# Epoch: 222 	Training Loss: 0.445395 	Validation Loss: 0.439290
# Epoch: 223 	Training Loss: 0.447627 	Validation Loss: 0.445350
# Epoch: 224 	Training Loss: 0.447006 	Validation Loss: 0.438822
# Epoch: 225 	Training Loss: 0.444550 	Validation Loss: 0.440074
# Epoch: 226 	Training Loss: 0.443973 	Validation Loss: 0.440913
# Epoch: 227 	Training Loss: 0.444843 	Validation Loss: 0.441868
# Epoch: 228 	Training Loss: 0.443615 	Validation Loss: 0.440955
# Epoch: 229 	Training Loss: 0.443924 	Validation Loss: 0.439791
# Epoch: 230 	Training Loss: 0.444505 	Validation Loss: 0.440406
# Epoch: 231 	Training Loss: 0.444401 	Validation Loss: 0.442107
# Epoch: 232 	Training Loss: 0.445229 	Validation Loss: 0.440855
# Epoch: 233 	Training Loss: 0.443944 	Validation Loss: 0.446290
# Epoch: 234 	Training Loss: 0.445005 	Validation Loss: 0.444944
# Epoch: 235 	Training Loss: 0.446708 	Validation Loss: 0.440868
# Epoch: 236 	Training Loss: 0.444951 	Validation Loss: 0.446541
# Epoch: 237 	Training Loss: 0.445825 	Validation Loss: 0.440334
# Epoch: 238 	Training Loss: 0.443942 	Validation Loss: 0.439310
# Epoch: 239 	Training Loss: 0.446736 	Validation Loss: 0.444897
# Epoch: 240 	Training Loss: 0.447701 	Validation Loss: 0.444454
# Epoch: 241 	Training Loss: 0.443603 	Validation Loss: 0.440715
# Epoch: 242 	Training Loss: 0.445592 	Validation Loss: 0.437817
# Epoch: 243 	Training Loss: 0.446243 	Validation Loss: 0.443668
# Epoch: 244 	Training Loss: 0.445183 	Validation Loss: 0.443221
# Epoch: 245 	Training Loss: 0.445963 	Validation Loss: 0.437764
# Epoch: 246 	Training Loss: 0.443278 	Validation Loss: 0.437398
# Epoch: 247 	Training Loss: 0.445379 	Validation Loss: 0.443770
# Epoch: 248 	Training Loss: 0.444397 	Validation Loss: 0.436453
# Epoch: 249 	Training Loss: 0.446433 	Validation Loss: 0.439947
# Epoch: 250 	Training Loss: 0.446642 	Validation Loss: 0.448098
# Epoch: 251 	Training Loss: 0.445913 	Validation Loss: 0.442788
# Epoch: 252 	Training Loss: 0.445125 	Validation Loss: 0.437247
# Epoch: 253 	Training Loss: 0.446344 	Validation Loss: 0.442010
# Epoch: 254 	Training Loss: 0.444920 	Validation Loss: 0.439856
# Epoch: 255 	Training Loss: 0.445643 	Validation Loss: 0.438964
# Epoch: 256 	Training Loss: 0.446141 	Validation Loss: 0.440055
# Epoch: 257 	Training Loss: 0.444940 	Validation Loss: 0.440158
# Epoch: 258 	Training Loss: 0.444027 	Validation Loss: 0.441236
# Epoch: 259 	Training Loss: 0.444707 	Validation Loss: 0.441748
# Epoch: 260 	Training Loss: 0.443880 	Validation Loss: 0.440054
# Epoch: 261 	Training Loss: 0.446558 	Validation Loss: 0.439405
# Epoch: 262 	Training Loss: 0.444810 	Validation Loss: 0.446665
# Epoch: 263 	Training Loss: 0.443794 	Validation Loss: 0.437565
# Epoch: 264 	Training Loss: 0.445166 	Validation Loss: 0.438994
# Epoch: 265 	Training Loss: 0.444113 	Validation Loss: 0.440057
# Epoch: 266 	Training Loss: 0.443723 	Validation Loss: 0.438697
# Epoch: 267 	Training Loss: 0.446918 	Validation Loss: 0.437946
# Epoch: 268 	Training Loss: 0.445075 	Validation Loss: 0.440972
# Epoch: 269 	Training Loss: 0.445131 	Validation Loss: 0.439354
# Epoch: 270 	Training Loss: 0.443708 	Validation Loss: 0.440437
# Epoch: 271 	Training Loss: 0.446416 	Validation Loss: 0.443004
# Epoch: 272 	Training Loss: 0.445036 	Validation Loss: 0.440843
# Epoch: 273 	Training Loss: 0.445818 	Validation Loss: 0.442504
# Epoch: 274 	Training Loss: 0.446026 	Validation Loss: 0.443530
# Epoch: 275 	Training Loss: 0.445686 	Validation Loss: 0.439800
# Epoch: 276 	Training Loss: 0.446793 	Validation Loss: 0.444948
# Epoch: 277 	Training Loss: 0.446345 	Validation Loss: 0.442255
# Epoch: 278 	Training Loss: 0.446886 	Validation Loss: 0.447091
# Epoch: 279 	Training Loss: 0.444464 	Validation Loss: 0.439439
# Epoch: 280 	Training Loss: 0.442928 	Validation Loss: 0.448943
# Epoch: 281 	Training Loss: 0.444514 	Validation Loss: 0.439767
# Epoch: 282 	Training Loss: 0.444908 	Validation Loss: 0.439941
# Epoch: 283 	Training Loss: 0.444065 	Validation Loss: 0.441391
# Epoch: 284 	Training Loss: 0.443564 	Validation Loss: 0.439668
# Epoch: 285 	Training Loss: 0.444130 	Validation Loss: 0.436748
# Epoch: 286 	Training Loss: 0.444891 	Validation Loss: 0.440133
# Epoch: 287 	Training Loss: 0.442893 	Validation Loss: 0.442222
# Epoch: 288 	Training Loss: 0.444550 	Validation Loss: 0.445371
# Epoch: 289 	Training Loss: 0.445659 	Validation Loss: 0.444161
# Epoch: 290 	Training Loss: 0.445986 	Validation Loss: 0.439549
# Epoch: 291 	Training Loss: 0.444836 	Validation Loss: 0.439090
# Epoch: 292 	Training Loss: 0.443048 	Validation Loss: 0.438908
# Epoch: 293 	Training Loss: 0.446867 	Validation Loss: 0.442642
# Epoch: 294 	Training Loss: 0.443577 	Validation Loss: 0.439269
# Epoch: 295 	Training Loss: 0.444129 	Validation Loss: 0.439958
# Epoch: 296 	Training Loss: 0.444003 	Validation Loss: 0.445944
# Epoch: 297 	Training Loss: 0.444898 	Validation Loss: 0.437087
# Epoch: 298 	Training Loss: 0.445644 	Validation Loss: 0.438638
# Epoch: 299 	Training Loss: 0.445037 	Validation Loss: 0.446739
# Epoch: 300 	Training Loss: 0.446688 	Validation Loss: 0.443020
# Training Complete!
# <All keys matched successfully>

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.legend(frameon=False)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

def calcROC(model, X, y):
  ''' Compute Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores. '''

  print('ROC AUC Score:',roc_auc_score(y, model.predict_proba(X)[:, 1]))

  plot_roc_curve(model, X, y)  
  plt.show()

# %%
def test(loaders, model, criterion, use_cuda):
    
    print("Begin Test!")
    
    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.
    
    y_pred_list = []
    target_list = []
    y_true = []
    y_pred = []

    model.eval()
    with torch.no_grad():
      for batch_idx, (data, target) in enumerate(loaders['test']):
          # move to GPU
          if use_cuda:
              data, target = data.cuda(), target.cuda()
          # forward pass: compute predicted outputs by passing inputs to the model
          output = model(data)
          output = output.view(-1)
          target = target.unsqueeze(0).view(-1)
          target_list.append(target.cpu().numpy())
          # calculate the loss
          loss = criterion(output, target)
          # update average test loss 
          test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
          # convert output probabilities to predicted class
          #plt.plot(torch.sigmoid(output.data))
          pred = torch.round(torch.sigmoid(output.data))
          y_pred_list.append(pred.cpu().numpy())
          y_pred.append(output.data.cpu().numpy())
          #pred = output.data.max(1, keepdim=True)[1]
          # compare predictions to true label
          correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
          total += data.size(0)

    y_pred_list = [item for sublist in y_pred_list for item in sublist]
    target_list = [item for sublist in target_list for item in sublist]

    fpr, tpr, thresholds = roc_curve(target_list, y_pred_list)
    roc_auc = auc(fpr, tpr)

    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (100. * correct / total, correct, total))

    print('\nConfusion Matrix:\n')
    print(confusion_matrix(target_list, y_pred_list))

    print('\nClassification Report:\n')
    print(classification_report(target_list, y_pred_list))

    # Calculate the ROC Curve and AUC score for the DNN Classifier
    print('\nROC AUC Score:\n')
    print(roc_auc_score(target_list, y_pred_list))

    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
# call test function    
test(loaders, model, criterion, use_cuda)
# Out:
# Begin Test!
# Test Loss: 0.431286
#
#
# Test Accuracy: 77% (10334/13301)
#
# Confusion Matrix:
#
# [[4876 1927]
#  [1040 5458]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.72      0.77      6803
#          1.0       0.74      0.84      0.79      6498
#
#     accuracy                           0.78     13301
#    macro avg       0.78      0.78      0.78     13301
# weighted avg       0.78      0.78      0.78     13301
#
#
# ROC AUC Score:
#
# 0.7783466838155111
